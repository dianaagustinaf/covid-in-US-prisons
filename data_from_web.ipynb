# %%
import pandas as pd

# %%
#url for reading the SS table with state names and abbreviations
url = "https://www.ssa.gov/international/coc-docs/states.html"

#url for reading the data from worldometers data showing covid deaths in every US state
url1 = "https://www.worldometers.info/coronavirus/country/us/"

# %% [markdown]
# ## Scrapping and cleaning data from Social Security website

# %%
state_abbreviations = pd.read_html(url)

# %%
print(state_abbreviations)
# Out:
# [                       0   1
# 0                ALABAMA  AL
# 1                 ALASKA  AK
# 2         AMERICAN SAMOA  AS
# 3                ARIZONA  AZ
# 4               ARKANSAS  AR
# 5             CALIFORNIA  CA
# 6               COLORADO  CO
# 7            CONNECTICUT  CT
# 8               DELAWARE  DE
# 9   DISTRICT OF COLUMBIA  DC
# 10               FLORIDA  FL
# 11               GEORGIA  GA
# 12                  GUAM  GU
# 13                HAWAII  HI
# 14                 IDAHO  ID
# 15              ILLINOIS  IL
# 16               INDIANA  IN
# 17                  IOWA  IA
# 18                KANSAS  KS
# 19              KENTUCKY  KY
# 20             LOUISIANA  LA
# 21                 MAINE  ME
# 22              MARYLAND  MD
# 23         MASSACHUSETTS  MA
# 24              MICHIGAN  MI
# 25             MINNESOTA  MN
# 26           MISSISSIPPI  MS
# 27              MISSOURI  MO
# 28               MONTANA  MT
# 29              NEBRASKA  NE
# 30                NEVADA  NV
# 31         NEW HAMPSHIRE  NH
# 32            NEW JERSEY  NJ
# 33            NEW MEXICO  NM
# 34              NEW YORK  NY
# 35        NORTH CAROLINA  NC
# 36          NORTH DAKOTA  ND
# 37   NORTHERN MARIANA IS  MP
# 38                  OHIO  OH
# 39              OKLAHOMA  OK
# 40                OREGON  OR
# 41          PENNSYLVANIA  PA
# 42           PUERTO RICO  PR
# 43          RHODE ISLAND  RI
# 44        SOUTH CAROLINA  SC
# 45          SOUTH DAKOTA  SD
# 46             TENNESSEE  TN
# 47                 TEXAS  TX
# 48                  UTAH  UT
# 49               VERMONT  VT
# 50              VIRGINIA  VA
# 51        VIRGIN ISLANDS  VI
# 52            WASHINGTON  WA
# 53         WEST VIRGINIA  WV
# 54             WISCONSIN  WI
# 55               WYOMING  WY]

# %%
type(state_abbreviations)
# Out:
# list

# %%
df = state_abbreviations[0]

# %%
state_abbreviations_df = pd.DataFrame(df)

# %%
state_abbreviations_df.head()
# Out:
#                 0   1
# 0         ALABAMA  AL
# 1          ALASKA  AK
# 2  AMERICAN SAMOA  AS
# 3         ARIZONA  AZ
# 4        ARKANSAS  AR

# %%
state_abbreviations_df.rename(columns={0: "state", 1: "state_abbreviation"}, inplace = True)

# %% [markdown]
# # Scrapping data from Worldometer

# %%
## Reading data from worldometer site. The data is held in an object named df1 

from urllib.request import Request, urlopen

req = Request("https://www.worldometers.info/coronavirus/country/us/", headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()


tables = pd.read_html(webpage)
df1 = tables[0]
print(df1.head())
# Out:
#      #    USAState  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0  NaN   USA Total    85440340       NaN    1030415.0        NaN
# 1  1.0  California     9508467       NaN      91432.0        NaN
# 2  2.0       Texas     6907298       NaN      88777.0        NaN
# 3  3.0     Florida     6146564       NaN      74400.0        NaN
# 4  4.0    New York     5559628       NaN      69395.0        NaN
#
#    TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop    TotalTests  \
# 0      81851405.0    2558520.0          258126.0         3113.0  1.023826e+09
# 1       9048705.0     368330.0          240646.0         2314.0  1.655536e+08
# 2       6721363.0      97158.0          238217.0         3062.0  6.508263e+07
# 3       5877677.0     194487.0          286183.0         3464.0  5.811293e+07
# 4       5390788.0      99445.0          285790.0         3567.0  1.105116e+08
#
#    Tests/ 1M pop  Population                            Source    Projections
# 0      3093107.0         NaN                               NaN            NaN
# 1      4189935.0  39512223.0              [view by county] [1]  [projections]
# 2      2244547.0  28995881.0      [view by county] [1] [2] [3]  [projections]
# 3      2705729.0  21477737.0  [view by county] [1] [2] [3] [4]  [projections]
# 4      5680791.0  19453561.0      [view by county] [1] [2] [3]  [projections]

# %%
#converting df1 into a dataframe named state_covid_data
state_covid_data = pd.DataFrame(df1)

# %%
state_covid_data.head()
# Out:
#      #    USAState  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0  NaN   USA Total    85440340       NaN    1030415.0        NaN
# 1  1.0  California     9508467       NaN      91432.0        NaN
# 2  2.0       Texas     6907298       NaN      88777.0        NaN
# 3  3.0     Florida     6146564       NaN      74400.0        NaN
# 4  4.0    New York     5559628       NaN      69395.0        NaN
#
#    TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop    TotalTests  \
# 0      81851405.0    2558520.0          258126.0         3113.0  1.023826e+09
# 1       9048705.0     368330.0          240646.0         2314.0  1.655536e+08
# 2       6721363.0      97158.0          238217.0         3062.0  6.508263e+07
# 3       5877677.0     194487.0          286183.0         3464.0  5.811293e+07
# 4       5390788.0      99445.0          285790.0         3567.0  1.105116e+08
#
#    Tests/ 1M pop  Population                            Source    Projections
# 0      3093107.0         NaN                               NaN            NaN
# 1      4189935.0  39512223.0              [view by county] [1]  [projections]
# 2      2244547.0  28995881.0      [view by county] [1] [2] [3]  [projections]
# 3      2705729.0  21477737.0  [view by county] [1] [2] [3] [4]  [projections]
# 4      5680791.0  19453561.0      [view by county] [1] [2] [3]  [projections]

# %%
#cleaning data by removing columns that are not needed
#and removing rows with USA total as it is not needed row [0] and row [64]
state_covid_data.drop(columns = ['#', 'NewCases', 'NewDeaths','Source', 'Projections', 
                                'TotalRecovered','ActiveCases', 
                                 'Deaths/1M pop'], axis = 1, inplace=True)
state_covid_data.drop([0, 64], inplace = True)

# %%
state_covid_data.columns
# Out:
# Index(['USAState', 'TotalCases', 'TotalDeaths', 'Tot Cases/1M pop',
#        'TotalTests', 'Tests/ 1M pop', 'Population'],
#       dtype='object')

# %%
state_covid_data.head(63)
# Out:
#                  USAState  TotalCases  TotalDeaths  Tot Cases/1M pop  \
# 1              California     9508467      91432.0          240646.0
# 2                   Texas     6907298      88777.0          238217.0
# 3                 Florida     6146564      74400.0          286183.0
# 4                New York     5559628      69395.0          285790.0
# 5                Illinois     3274360      38114.0          258397.0
# ..                    ...         ...          ...               ...
# 59        Federal Prisons       69247        302.0               NaN
# 60          Navajo Nation       54021       1783.0               NaN
# 61    Grand Princess Ship         122          7.0               NaN
# 62      Wuhan Repatriated           3          NaN               NaN
# 63  Diamond Princess Ship          46          NaN               NaN
#
#      TotalTests  Tests/ 1M pop  Population
# 1   165553649.0      4189935.0  39512223.0
# 2    65082630.0      2244547.0  28995881.0
# 3    58112932.0      2705729.0  21477737.0
# 4   110511605.0      5680791.0  19453561.0
# 5    57898053.0      4569040.0  12671821.0
# ..          ...            ...         ...
# 59     129677.0            NaN         NaN
# 60     529248.0            NaN         NaN
# 61          NaN            NaN         NaN
# 62          3.0            NaN         NaN
# 63         46.0            NaN         NaN
#
# [63 rows x 7 columns]

# %%
state_covid_data.rename(columns={"USAState": "state"}, inplace = True)

# %%
state_covid_data.head()
# Out:
#         state  TotalCases  TotalDeaths  Tot Cases/1M pop   TotalTests  \
# 1  California     9508467      91432.0          240646.0  165553649.0
# 2       Texas     6907298      88777.0          238217.0   65082630.0
# 3     Florida     6146564      74400.0          286183.0   58112932.0
# 4    New York     5559628      69395.0          285790.0  110511605.0
# 5    Illinois     3274360      38114.0          258397.0   57898053.0
#
#    Tests/ 1M pop  Population
# 1      4189935.0  39512223.0
# 2      2244547.0  28995881.0
# 3      2705729.0  21477737.0
# 4      5680791.0  19453561.0
# 5      4569040.0  12671821.0

# %%
state_abbreviations_df.head()
# Out:
#             state state_abbreviation
# 0         ALABAMA                 AL
# 1          ALASKA                 AK
# 2  AMERICAN SAMOA                 AS
# 3         ARIZONA                 AZ
# 4        ARKANSAS                 AR

# %%
# There are only 50 states in the USA this is less than the number of rows on the state_covid_data df therefore
# Some rows in the state_covid_data df might need to be removed as these show data from US territories not states
# howver data from the row with index 59 might be important as it shows data from federal prison which  
# might be important in this project

# %%
state_covid_datadf = pd.merge(state_abbreviations_df, state_covid_data, how = 'inner', on = 'state' )

# %%
state_covid_datadf.shape
# Out:
# (0, 8)

# %%
state_abbreviations_df['state'] = state_abbreviations_df['state'].str.lower()

# %%
state_abbreviations_df.head()
# Out:
#             state state_abbreviation
# 0         alabama                 AL
# 1          alaska                 AK
# 2  american samoa                 AS
# 3         arizona                 AZ
# 4        arkansas                 AR

# %%
state_covid_data['state'] = state_covid_data['state'].str.lower()

# %%
state_covid_data.head()
# Out:
#         state  TotalCases  TotalDeaths  Tot Cases/1M pop   TotalTests  \
# 1  california     9508467      91432.0          240646.0  165553649.0
# 2       texas     6907298      88777.0          238217.0   65082630.0
# 3     florida     6146564      74400.0          286183.0   58112932.0
# 4    new york     5559628      69395.0          285790.0  110511605.0
# 5    illinois     3274360      38114.0          258397.0   57898053.0
#
#    Tests/ 1M pop  Population
# 1      4189935.0  39512223.0
# 2      2244547.0  28995881.0
# 3      2705729.0  21477737.0
# 4      5680791.0  19453561.0
# 5      4569040.0  12671821.0

# %%
state_covid_datadf = pd.merge(state_abbreviations_df, state_covid_data, how = 'inner', on = 'state' )

# %%
state_covid_datadf.head(55)
# Out:
#                    state state_abbreviation  TotalCases  TotalDeaths  \
# 0                alabama                 AL     1310513      19651.0
# 1                 alaska                 AK      251425       1252.0
# 2         american samoa                 AS        6110         31.0
# 3                arizona                 AZ     2049627      30299.0
# 4               arkansas                 AR      841675      11461.0
# 5             california                 CA     9508467      91432.0
# 6               colorado                 CO     1426298      13308.0
# 7            connecticut                 CT      803748      10937.0
# 8               delaware                 DE      273722       2942.0
# 9   district of columbia                 DC      148270       1342.0
# 10               florida                 FL     6146564      74400.0
# 11               georgia                 GA     2556044      38198.0
# 12                  guam                 GU       48865        362.0
# 13                hawaii                 HI      274495       1451.0
# 14                 idaho                 ID      450337       4939.0
# 15              illinois                 IL     3274360      38114.0
# 16               indiana                 IN     1727818      23692.0
# 17                  iowa                 IA      876666       9588.0
# 18                kansas                 KS      785916       8939.0
# 19              kentucky                 KY     1349478      15917.0
# 20             louisiana                 LA     1254640      17319.0
# 21                 maine                 ME      261031       2345.0
# 22              maryland                 MD     1078122      14581.0
# 23         massachusetts                 MA     1855500      20544.0
# 24              michigan                 MI     2501863      36218.0
# 25             minnesota                 MN     1500556      12920.0
# 26           mississippi                 MS      805800      12466.0
# 27              missouri                 MO     1440814      20454.0
# 28               montana                 MT      276192       3385.0
# 29              nebraska                 NE      485377       4275.0
# 30                nevada                 NV      735021      10872.0
# 31         new hampshire                 NH      323326       2528.0
# 32            new jersey                 NJ     2370508      33651.0
# 33            new mexico                 NM      532240       7732.0
# 34              new york                 NY     5559628      69395.0
# 35        north carolina                 NC     2744935      24644.0
# 36          north dakota                 ND      243769       2276.0
# 37                  ohio                 OH     2743577      38590.0
# 38              oklahoma                 OK     1045574      14419.0
# 39                oregon                 OR      757210       7607.0
# 40          pennsylvania                 PA     2907324      45147.0
# 41           puerto rico                 PR      646707       4330.0
# 42          rhode island                 RI      389901       3565.0
# 43        south carolina                 SC     1495762      17905.0
# 44          south dakota                 SD      239704       2927.0
# 45             tennessee                 TN     2053638      26403.0
# 46                 texas                 TX     6907298      88777.0
# 47                  utah                 UT      943368       4765.0
# 48               vermont                 VT      129854        654.0
# 49              virginia                 VA     1770620      20358.0
# 50            washington                 WA     1565696      12888.0
# 51         west virginia                 WV      512571       6933.0
# 52             wisconsin                 WI     1664367      14527.0
# 53               wyoming                 WY      157861       1820.0
#
#     Tot Cases/1M pop   TotalTests  Tests/ 1M pop  Population
# 0           267278.0    7688520.0      1568066.0   4903185.0
# 1           343690.0    4107614.0      5614985.0    731545.0
# 2                NaN      16770.0            NaN         NaN
#                    state state_abbreviation  TotalCases  TotalDeaths  \
# 0                alabama                 AL   1310513.0      19651.0
# 1                 alaska                 AK    251425.0       1252.0
# 2         american samoa                 AS      6110.0         31.0
# 3                arizona                 AZ   2049627.0      30299.0
# 4               arkansas                 AR    841675.0      11461.0
# 5             california                 CA   9508467.0      91432.0
# 6               colorado                 CO   1426298.0      13308.0
# 7            connecticut                 CT    803748.0      10937.0
# 8               delaware                 DE    273722.0       2942.0
# 9   district of columbia                 DC    148270.0       1342.0
# 10               florida                 FL   6146564.0      74400.0
# 11               georgia                 GA   2556044.0      38198.0
# 12                  guam                 GU     48865.0        362.0
# 13                hawaii                 HI    274495.0       1451.0
# 14                 idaho                 ID    450337.0       4939.0
# 15              illinois                 IL   3274360.0      38114.0
# 16               indiana                 IN   1727818.0      23692.0
# 17                  iowa                 IA    876666.0       9588.0
# 18                kansas                 KS    785916.0       8939.0
# 19              kentucky                 KY   1349478.0      15917.0
# 20             louisiana                 LA   1254640.0      17319.0
# 21                 maine                 ME    261031.0       2345.0
# 22              maryland                 MD   1078122.0      14581.0
# 23         massachusetts                 MA   1855500.0      20544.0
# 24              michigan                 MI   2501863.0      36218.0
# 25             minnesota                 MN   1500556.0      12920.0
# 26           mississippi                 MS    805800.0      12466.0
# 27              missouri                 MO   1440814.0      20454.0
# 28               montana                 MT    276192.0       3385.0
# 29              nebraska                 NE    485377.0       4275.0
# 30                nevada                 NV    735021.0      10872.0
# 31         new hampshire                 NH    323326.0       2528.0
# 32            new jersey                 NJ   2370508.0      33651.0
# 33            new mexico                 NM    532240.0       7732.0
# 34              new york                 NY   5559628.0      69395.0
# 35        north carolina                 NC   2744935.0      24644.0
# 36          north dakota                 ND    243769.0       2276.0
# 37   northern mariana is                 MP         NaN          NaN
# 38                  ohio                 OH   2743577.0      38590.0
# 39              oklahoma                 OK   1045574.0      14419.0
# 40                oregon                 OR    757210.0       7607.0
# 41          pennsylvania                 PA   2907324.0      45147.0
# 42           puerto rico                 PR    646707.0       4330.0
# 43          rhode island                 RI    389901.0       3565.0
# 44        south carolina                 SC   1495762.0      17905.0
# 45          south dakota                 SD    239704.0       2927.0
# 46             tennessee                 TN   2053638.0      26403.0
# 47                 texas                 TX   6907298.0      88777.0
# 48                  utah                 UT    943368.0       4765.0
# 49               vermont                 VT    129854.0        654.0
# 50              virginia                 VA   1770620.0      20358.0
# 51        virgin islands                 VI         NaN          NaN
# 52            washington                 WA   1565696.0      12888.0
# 53         west virginia                 WV    512571.0       6933.0
# 54             wisconsin                 WI   1664367.0      14527.0
# 55               wyoming                 WY    157861.0       1820.0
#
#     Tot Cases/1M pop   TotalTests  Tests/ 1M pop  Population
# 0           267278.0    7688520.0      1568066.0   4903185.0
# 1           343690.0    4107614.0      5614985.0    731545.0
# 2                NaN      16770.0            NaN         NaN
# 3           281592.0   19534476.0      2683780.0   7278717.0
